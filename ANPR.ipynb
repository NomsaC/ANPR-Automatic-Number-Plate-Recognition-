# %%
# !python -m pip install easyocr
# !python -m pip install imutils
# Out:
# Requirement already satisfied: easyocr in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (1.7.1)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: torch in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (2.0.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (0.15.2)
# Requirement already satisfied: opencv-python-headless in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (4.8.0.76)
# Requirement already satisfied: scipy in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (1.11.2)
# Requirement already satisfied: numpy in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (1.24.4)
# Requirement already satisfied: Pillow in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (10.0.0)
# Requirement already satisfied: scikit-image in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (0.21.0)
# Requirement already satisfied: python-bidi in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (2.0.1)
# Requirement already satisfied: pyclipper in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: requests in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from torchvision>=0.5->easyocr) (2.31.0)
# Requirement already satisfied: filelock in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from torch->easyocr) (3.12.2)
# Requirement already satisfied: typing-extensions in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from torch->easyocr) (4.7.1)
# Requirement already satisfied: sympy in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from torch->easyocr) (3.1)
# Requirement already satisfied: jinja2 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: six in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr) (2.31.3)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr) (2023.8.30)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr) (23.1)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr) (0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch->easyocr) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# Requirement already satisfied: imutils in c:\users\nomsa\appdata\local\programs\python\python311\lib\site-packages (0.5.4)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr #helps extract text from images

# %%
img = cv2.imread('image1.jpg')
resized_img = cv2.resize(img, (620,480) ) #resize image just incase you meet large pictures
gray = cv2.cvtColor(resized_img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
edged = cv2.Canny(bfilter, 30, 200) #Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

location
# Out:
# array([[[117, 229]],
#
#        [[236, 238]],
#
#        [[241, 210]],
#
#        [[125, 201]]], dtype=int32)

# %%
mask = np.zeros(img.shape[:2], np.uint8)

new_image = cv2.drawContours(mask, [location], 0, 255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# Display the image
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[4, 4], [124, 4], [124, 36], [4, 36]], 'HR.26 BR 9044', 0.8223900942654843)]

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
